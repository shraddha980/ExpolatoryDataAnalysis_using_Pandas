# %% [markdown]
# Dataframe ke table hota hai basically. Dataframe ka har ke column ek series hai. A combination of series becomes one dataframe.
# Agar dataframe banana hai toh woh hum lists se bana sakte hai dictionary se bana sakte hai and aise sab alag alag tarike se bana sakte hai

# %% [markdown]
# ### Dataframe from Lists

# %%
#dataframe using 2D lists

# %%
import pandas as pd
import numpy as np

# %%
student_data = [
    [120,130,3000],
    [30,45,4500],
    [45,34,7890],
    [120,130,3000]
]

# %%
student = pd.DataFrame(student_data,columns = ['marks','iq','package'])

# %%
student
# Out:
#    marks   iq  package
# 0    120  130     3000
# 1     30   45     4500
# 2     45   34     7890
# 3    120  130     3000

# %%
#making dataframe from a dictionary
student_dict = {
    'name': ["shraddha","Gaurav","shashank"],
    'marks' : [120,130,140],
    'iq' : [30,45,56],
    'package' : [700,500,800]
}

# %%
student_dict = pd.DataFrame(student_dict)

# %%
#any structure that has rows and columns is DataFrame for Pandas

# %%
movies = pd.read_csv("movies.csv")

# %%
ipl = pd.read_csv("ipl-matches.csv")

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ## DataFrame Attributes and Methods

# %%
movies.shape
# Out:
# (1629, 18)

# %%
#finding out ki ajkal kitne movies aur kitne matches hue

# %%
ipl.shape
# Out:
# (950, 20)

# %%
#Dtypes: to know the datatype of data

# %%
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
#index : to fetch index of dataframe

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
#columns : ye mujhe saare columns de dega jo dataset mai present hai

# %%
#ye sare attribues jaise columns aur values hume output array ke format mai denge

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
student.columns
# Out:
# Index(['marks', 'iq', 'package'], dtype='object')

# %%
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
student.values
# Out:
# array([[ 120,  130, 3000],
#        [  30,   45, 4500],
#        [  45,   34, 7890]], dtype=int64)

# %% [markdown]
# jab aapne series mai values function lagaya tha tab aapko attributes mil rahe the in form of 1D array kyunki sab series format mai tha. but jab aapne student ya ipl mai lagaya tab aapko saare output mila inform of multiple arrays because boht saare rows hai

# %%
#head : jab aapko starting ke panch bacche dekhne hai.

# %%
ipl.head(5)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
#tail : agar apko end ke 5 bacche dekhne hai

# %%
ipl.tail(5)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
#sample : agar ek dataset hai jaha starting mai 5 bacche strong hai, end ke 5 bacche weak hai toh hum sample use kar sakte hai.
#Sample hum random sample nikal ke bacche de dega

# %%
ipl.sample(5)
# Out:
#           ID       City        Date   Season MatchNumber  \
# 800   419139    Kolkata  2010-04-04  2009/10          34
# 365  1082598     Indore  2017-04-10     2017           8
# 906   336027    Kolkata  2008-05-20  2007/08          44
# 681   548327  Bangalore  2012-04-17     2012          21
# 483   829721  Ahmedabad  2015-04-14     2015           9
#
#                            Team1                        Team2  \
# 800        Kolkata Knight Riders              Kings XI Punjab
# 365              Kings XI Punjab  Royal Challengers Bangalore
# 906        Kolkata Knight Riders             Rajasthan Royals
# 681  Royal Challengers Bangalore                Pune Warriors
# 483             Rajasthan Royals               Mumbai Indians
#
#                             Venue                   TossWinner TossDecision  \
# 800                  Eden Gardens        Kolkata Knight Riders          bat
# 365        Holkar Cricket Stadium  Royal Challengers Bangalore          bat
# ...

# %%
#info

# %% [markdown]
# info hume information deta hai on dataset completely, jaise kitni nonnull values hai, kitne object datatype hai kitna float datatype hai, kitna kb of space occupy kar raha hai appka dataset

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#describe : jitne bhi numerical columns hai bas woh dikhai denge. aur kuch statistical values dikhai denge

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %% [markdown]
# toh upar ke dataset se hume dikhai deta hai ki average rating of all the movies is 5.5 jo ki kafi kam hai dekha jaye toh,
# next is ki kisi movie ka rating 0 bhi hai, fir aise bhi hai ki 25% of movies ka rating 25percent se kam hai, 75% movies ka rating greater than 6.8 hai aur 50% of movies ka rating 4.60 around hai.Maximum rating 9.40 tak hai.

# %%
ipl.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
ipl.isnull().sum()
#har column ke andar kitni missing values hai
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
#duplicate

# %%
ipl.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %%
ipl.duplicated().sum()
# Out:
# 0

# %%
student.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
student.duplicated().sum()
# Out:
# 1

# %% [markdown]
# agar duplicate rows nahi hai toh false dega aur agar duplicated hai toh woh True de dega. But duplicated values toh hum uska sum bhi nikal sakte hai

# %%
#rename : ho sakta hai ki koi column ka naam bada hai aur apko usko rename karna hai toh rename function use kar sakte ho

# %%
student.rename(columns={'marks':'percent','package':'lpa'})
# Out:
#    percent   iq   lpa
# 0      120  130  3000
# 1       30   45  4500
# 2       45   34  7890
# 3      120  130  3000

# %% [markdown]
# but ye permanent rename nahi karta agar permanent rename karna hai toh inplace = True kar do

# %%
student.rename(columns={'marks':'percent','package':'lpa'},inplace = True)

# %% [markdown]
# ### last mai small bracket lagana hai ya nahi ye practice se hi pata chalta hai

# %% [markdown]
# ## Mathematical functions

# %% [markdown]
# Toh app boht saare mathematical functions apne data ke upar laga sakte ho. jaise sum, mean, max etc. agar strings hai data mai toh woh strings ko concat kar dega but hum aise nahi karte strings ko concat, incase of sum aur float ko bhi concat kar dega incase of dataset

# %%
movies.sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
student.sum(axis=0) #column wise sum
# Out:
# percent      315
# iq           339
# lpa        18390
# dtype: int64

# %% [markdown]
# ismai isne kya kiya ki saare values ek column mai jo hoti hai usko jod diya, sum kar diya

# %%
student.sum(axis=1) #row wise sum
# Out:
# 0    3250
# 1    4575
# 2    7969
# 3    3250
# dtype: int64

# %% [markdown]
# ek hidden parameter hota hai axis, ya axis mai row waise sum hogaya

# %%
student.mean(axis=0) # column wise mean deta hai
# Out:
# percent      78.75
# iq           84.75
# lpa        4597.50
# dtype: float64

# %%
student.mean(axis=1) # row wise mean deta hai
# Out:
# 0    1083.333333
# 1    1525.000000
# 2    2656.333333
# 3    1083.333333
# dtype: float64

# %% [markdown]
# app same kar sakte ho using mean, max, median, variance etc

# %% [markdown]
# ### Fetching columns from a dataset 1) Single Columns 2) Multiple Columns

# %%
ipl['Season']
# Out:
# 0         2022
# 1         2022
# 2         2022
# 3         2022
# 4         2022
#         ...
# 945    2007/08
# 946    2007/08
# 947    2007/08
# 948    2007/08
# 949    2007/08
# Name: Season, Length: 950, dtype: object

# %% [markdown]
# ##### single column output will give a series output

# %%
ipl[['Date','Season','Team1']]
# Out:
#            Date   Season                        Team1
# 0    2022-05-29     2022             Rajasthan Royals
# 1    2022-05-27     2022  Royal Challengers Bangalore
# 2    2022-05-25     2022  Royal Challengers Bangalore
# 3    2022-05-24     2022             Rajasthan Royals
# 4    2022-05-22     2022          Sunrisers Hyderabad
# ..          ...      ...                          ...
# 945  2008-04-20  2007/08        Kolkata Knight Riders
# 946  2008-04-20  2007/08               Mumbai Indians
# 947  2008-04-19  2007/08             Delhi Daredevils
# 948  2008-04-19  2007/08              Kings XI Punjab
# 949  2008-04-18  2007/08  Royal Challengers Bangalore
#
# [950 rows x 3 columns]

# %% [markdown]
# ##### For multiple columns hum multiple columns in quotes de sakte hai aur, aur multiple columns hum ek list ke andar dete hai. iska output hume dataframe ke format mai milta hai

# %% [markdown]
# ### Selecting Rows from a dataset 1) loc    2) iloc

# %%
student_dict
# Out:
#        name  marks  iq  package
# 0  shraddha    120  30      700
# 1    Gaurav    130  45      500
# 2  shashank    140  56      800

# %%
student_dict.set_index('name',inplace = True)

# %%
student_dict
# Out:
#           marks  iq  package
# name
# shraddha    120  30      700
# Gaurav      130  45      500
# shashank    140  56      800

# %% [markdown]
# ##### iloc : Searches using index position
# ##### loc : Searches using index labels

# %%
student_dict.iloc[0]
# Out:
# marks      120
# iq          30
# package    700
# Name: shraddha, dtype: int64

# %%
type(student_dict.iloc[0])
# Out:
# pandas.core.series.Series

# %%
student_dict.loc['shraddha']
# Out:
# marks      120
# iq          30
# package    700
# Name: shraddha, dtype: int64

# %%
type(student_dict.loc['shraddha'])
# Out:
# pandas.core.series.Series

# %%
movies.iloc[1]
# Out:
# title_x                                                 Battalion 609
# imdb_id                                                     tt9472208
# poster_path                                                       NaN
# wiki_link                 https://en.wikipedia.org/wiki/Battalion_609
# title_y                                                 Battalion 609
# original_title                                          Battalion 609
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           131
# genres                                                            War
# imdb_rating                                                       4.1
# imdb_votes                                                         73
# story               The story revolves around a cricket match betw...
# ...

# %%
movies.iloc[1:5]
#gives multiple rows using index position
#single row nikaloge toh series milega, multiple rows nikaloge toh dataframe milega
# Out:
#                                 title_x    imdb_id  \
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
#                          title_y                 original_title  is_adult  \
# 1                  Battalion 609                  Battalion 609         0
# ...

# %%
movies.iloc[1:12:2]
#alternate movies
# Out:
#              title_x    imdb_id  \
# 1      Battalion 609  tt9472208
# 3    Why Cheat India  tt8108208
# 5        Soni (film)  tt6078866
# 7         Bombairiya  tt4971258
# 9   Thackeray (film)  tt7777196
# 11         Gully Boy  tt2395469
#
#                                           poster_path  \
# 1                                                 NaN
# 3   https://upload.wikimedia.org/wikipedia/en/thum...
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                          wiki_link          title_y  \
# 1      https://en.wikipedia.org/wiki/Battalion_609    Battalion 609
# 3    https://en.wikipedia.org/wiki/Why_Cheat_India  Why Cheat India
# 5        https://en.wikipedia.org/wiki/Soni_(film)             Soni
# 7         https://en.wikipedia.org/wiki/Bombairiya       Bombairiya
# ...

# %%
#fancy indexing
student_dict.loc[['shraddha','Gaurav']]
#multiple rows nikaloge ko dataframe milega
# Out:
#           marks  iq  package
# name
# shraddha    120  30      700
# Gaurav      130  45      500

# %%
movies.iloc[[0,1,5]]
#fancy indexing to fetch multiple locations/positions using index
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
student_dict.loc["shraddha":"shashank":2]
#loc mai range ke sath steps de sakte hai label ko
# Out:
#           marks  iq  package
# name
# shraddha    120  30      700
# shashank    140  56      800

# %%
student_dict.loc["shraddha":"shashank"]
#loc mai range de sakte hai
# Out:
#           marks  iq  package
# name
# shraddha    120  30      700
# Gaurav      130  45      500
# shashank    140  56      800

# %%
student_dict.iloc[0]
#labels hai but default index bhi hai waha pe jo zero hai
#kyunki pandas ka default index bhi hai laga hua waha pe
# Out:
# marks      120
# iq          30
# package    700
# Name: shraddha, dtype: int64

# %% [markdown]
# ### Selecting both rows and columns using loc and iloc

# %%
movies.iloc[0:3,0:3]
#giving index positions index
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:3,'title_x':'poster_path']
#giving names for loc
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
#whenever you create a dataframe sare rows ko internally ek dataframe assign ho jata hai even if rows and columns names ko. 
#pandas internally 0 : asie hi rakhega

# %% [markdown]
# ### Filtering Data

# %%
#find first two rows of Data
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
#find all the final winners from ipl data
mask = ipl['MatchNumber'] == 'Final'

# %%
mask
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: MatchNumber, Length: 950, dtype: bool

# %%
new_df = ipl[mask]

# %%
new_df
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %% [markdown]
# Upar wala answer find out karne k liye humne boht saare ways laga diye but hum isko ek line mai bhi kar sakte hai by applying fancy indexing and by also taking the output inside index like below

# %%
ipl[ipl["MatchNumber"] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
##How many super Overs have happened. 
##Super over is something which happens when both the teams have made the same amount of runs

# %%
ipl[ipl['SuperOver'] == 'Y'].shape
# Out:
# (14, 20)

# %% [markdown]
# ##### shape hume number of rows aur columns batata hai aur agar mai sirf [0] select karu shape k baad toh mujhe sirf number of rows bata dega

# %%
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
ipl[ipl['SuperOver'] == 'Y'].count()
# Out:
# ID                 14
# City               11
# Date               14
# Season             14
# MatchNumber        14
# Team1              14
# Team2              14
# Venue              14
# TossWinner         14
# TossDecision       14
# SuperOver          14
# WinningTeam        14
# WonBy              14
# Margin              0
# method              0
# Player_of_Match    14
# Team1Players       14
# Team2Players       14
# Umpire1            14
# Umpire2            14
# dtype: int64

# %%
#How many matches has CSK won in Kolkata?

# %% [markdown]
# ##### Guess karo hum yaha pe logical And kyu laga rahe ho. Becuase jab app first criteria index pe lagate ho toh appko ek boolean series mila tha as below similarly jab app dusara filter lagata ho toh appko aur ek series milta hai isliye hum logical AND nahi use karte balki hum ampersand and yani & ye use karte hai kyunki ye hume bit wise operation karke deta hai. Jab dono se True milega tabhi true lo agar dono se False mile toh False le lo

# %%
ipl[(ipl['WinningTeam'] == 'Chennai Super Kings')& (ipl['City']== 'Kolkata')]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
ipl['WinningTeam'] == 'Chennai Super Kings'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948     True
# 949    False
# Name: WinningTeam, Length: 950, dtype: bool

# %%
ipl['City']== 'Kolkata'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 945     True
# 946    False
# 947    False
# 948    False
# 949    False
# Name: City, Length: 950, dtype: bool

# %%
ipl[(ipl['WinningTeam'] == 'Chennai Super Kings')& (ipl['City'] == 'Kolkata')].shape
# Out:
# (5, 20)

# %%
ipl[(ipl['WinningTeam'] == 'Chennai Super Kings')& (ipl['City'] == 'Kolkata')].shape[0]
# Out:
# 5

# %%
#How many percent of Toss Winners have also won Actual Matches. Kyunki hume check karna hai ki kitne percent hai incidents 
#log toss k sath match bhi jeet chuke hai

# %%
ipl[(ipl["TossWinner"]) == (ipl["WinningTeam"])].shape
# Out:
# (489, 20)

# %%
(ipl[(ipl["TossWinner"]) == (ipl["WinningTeam"])].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
#find Movies imdb rating is greater than 8 and votes>100
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape
# Out:
# (43, 18)

# %%
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
movies[(movies['imdb_rating'] > 8.5) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 0

# %%
#length,count

# %%
#Action movies with rating higher than 8.7

# %%
movies[(movies['genres'].str.split("|").apply(lambda x:'Action' in x)) & (movies['imdb_rating'] > 5)]
#yaha pe humne kya kiya hai ki pehle genres ko string mai split kar diya hai, but kiske upar split kiya hai humne "|" iske upar
#aur fir humne usko leke ek cumstom function mai diya jo hai lamda, yaha pe x kya hai x list hai toh us list mai hum action 
#khoj rahe hai
# Out:
#                                title_x     imdb_id  \
# 0             Uri: The Surgical Strike   tt8291224
# 8     Manikarnika: The Queen of Jhansi   tt6903440
# 14                          Sonchiriya   tt8108200
# 16              Mard Ko Dard Nahi Hota   tt8055888
# 22                       Kesari (film)   tt6264938
# ...                                ...         ...
# 1603                 Mitti (2001 film)   tt0446159
# 1607           Nayak (2001 Hindi film)   tt0291376
# 1608                        One 2 Ka 4   tt0227194
# 1617               Officer (2001 film)   tt0265452
# 1627                             Daaka  tt10833860
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 8     https://upload.wikimedia.org/wikipedia/en/thum...
# 14    https://upload.wikimedia.org/wikipedia/en/thum...
# 16    https://upload.wikimedia.org/wikipedia/en/thum...
# 22    https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#second way to look for action is
movies[movies["genres"].str.contains('Action')]
# Out:
#                                title_x     imdb_id  \
# 0             Uri: The Surgical Strike   tt8291224
# 8     Manikarnika: The Queen of Jhansi   tt6903440
# 13                       Total Dhamaal   tt7639372
# 14                          Sonchiriya   tt8108200
# 16              Mard Ko Dard Nahi Hota   tt8055888
# ...                                ...         ...
# 1606   Hadh: Life on the Edge of Death   tt0396044
# 1607           Nayak (2001 Hindi film)   tt0291376
# 1608                        One 2 Ka 4   tt0227194
# 1617               Officer (2001 film)   tt0265452
# 1627                             Daaka  tt10833860
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 8     https://upload.wikimedia.org/wikipedia/en/thum...
# 13    https://upload.wikimedia.org/wikipedia/en/thum...
# 14    https://upload.wikimedia.org/wikipedia/en/thum...
# 16    https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ### Adding new columns in exiting dataset

# %%
student["country"] = "India"

# %%
student
#ek column ban chuka hai jiska saara value country ho chuka hai
# Out:
#    percent   iq   lpa country
# 0      120  130  3000   India
# 1       30   45  4500   India
# 2       45   34  7890   India
# 3      120  130  3000   India

# %%
movies.dropna(inplace=True)
#maximum rows hat gaye

# %%
movies["actors"].str.split("|").apply(lambda x:x[0])
# Out:
# 11             Ranveer Singh
# 34              Gavie Chahal
# 37        Ayushmann Khurrana
# 87         Sidharth Malhotra
# 96                Ajay Devgn
#                 ...
# 1600             Divya Dutta
# 1601               Anant Nag
# 1607             Anil Kapoor
# 1621    Priyanshu Chatterjee
# 1623          Karisma Kapoor
# Name: actors, Length: 298, dtype: object

# %%
movies['leadactor'] = movies["actors"].str.split("|").apply(lambda x:x[0])

# %%
movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 298 entries, 11 to 1623
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           298 non-null    object
#  1   imdb_id           298 non-null    object
#  2   poster_path       298 non-null    object
#  3   wiki_link         298 non-null    object
#  4   title_y           298 non-null    object
#  5   original_title    298 non-null    object
#  6   is_adult          298 non-null    int64
#  7   year_of_release   298 non-null    int64
#  8   runtime           298 non-null    object
#  9   genres            298 non-null    object
#  10  imdb_rating       298 non-null    float64
#  11  imdb_votes        298 non-null    int64
#  12  story             298 non-null    object
#  13  summary           298 non-null    object
#  14  tagline           298 non-null    object
#  15  actors            298 non-null    object
# ...

# %%
#Missing values ko pandas float ki tarah treat karta hai

# %% [markdown]
# ## Methods

# %% [markdown]
# #### <i> 1 ) value counts ( applicable to both series and dataframe ) </i>

# %%
data = pd.Series([1,1,2,2,3,3,4])

# %%
data.value_counts()
# Out:
# 1    2
# 2    2
# 3    2
# 4    1
# Name: count, dtype: int64

# %%
data_marks = pd.DataFrame([
    [120,120,130],
    [200,300,400],
    [12,13,14],
    [12,13,14]], columns = ['iq','marks','package'])

# %%
data_marks
# Out:
#     iq  marks  package
# 0  120    120      130
# 1  200    300      400
# 2   12     13       14
# 3   12     13       14

# %%
data_marks.value_counts() # telling us how many times pure ka pura row kitne baar aya hai ya duplicate hua hai. but real life mai
#utna useful nahi hai
# Out:
# iq   marks  package
# 12   13     14         2
# 120  120    130        1
# 200  300    400        1
# Name: count, dtype: int64

# %%
# 1) Find which player has won maximum man of the match award in final and semi final matches

# %%
ipl_data = pd.read_csv("ipl-matches.csv")

# %%
ipl_data
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl_data["Player_of_Match"].value_counts() # ye hume directly bas ye bata hai ki frequencies batata hai
# Out:
# Player_of_Match
# AB de Villiers    25
# CH Gayle          22
# DA Warner         18
# RG Sharma         18
# MS Dhoni          17
#                   ..
# CR Brathwaite      1
# Mohsin Khan        1
# A Zampa            1
# BCJ Cutting        1
# MF Maharoof        1
# Name: count, Length: 262, dtype: int64

# %%
~ipl_data["MatchNumber"].str.isdigit()
# Out:
# MatchNumber
# True    -893
# False    -59
# Name: count, dtype: int64

# %%
ipl[~ipl_data["MatchNumber"].str.isdigit()]["Player_of_Match"].value_counts()
# Out:
# Player_of_Match
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# ...

# %%
#Toss jitne ke baad teams batting karti hai ya bowling karti hai hume iska pie chart banana hai

# %%
TossD_pie = ipl_data['TossDecision'].value_counts()

# %%
TossD_pie
# Out:
# TossDecision
# field    599
# bat      351
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plot

# %%
TossD_pie.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#Find out how many matches has each team played

# %%
ipl_data['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
ipl_data['Team2'].value_counts()
# Out:
# Team2
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Kings XI Punjab                 98
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# Delhi Daredevils                76
# Deccan Chargers                 36
# Delhi Capitals                  34
# Pune Warriors                   23
# Gujarat Lions                   14
# Punjab Kings                    10
# Gujarat Titans                   9
# Rising Pune Supergiant           9
# Rising Pune Supergiants          7
# Lucknow Super Giants             7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
ipl_data['Team1'].value_counts() + ipl_data['Team2'].value_counts()
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %%
(ipl_data['Team1'].value_counts() + ipl_data['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
movies.head(10)
# Out:
#                      title_x     imdb_id  \
# 11                 Gully Boy   tt2395469
# 34             Yeh Hai India   tt5525846
# 37         Article 15 (film)  tt10324144
# 87                   Aiyaary   tt6774212
# 96          Raid (2018 film)   tt7363076
# 99                  Baaghi 2   tt6843812
# 100      October (2018 film)   tt7700730
# 105            Omerta (film)   tt6978268
# 106                    Raazi   tt7098658
# 112  Bhavesh Joshi Superhero   tt6129302
#
#                                            poster_path  \
# 11   https://upload.wikimedia.org/wikipedia/en/thum...
# 34   https://upload.wikimedia.org/wikipedia/en/thum...
# 37   https://upload.wikimedia.org/wikipedia/en/thum...
# 87   https://upload.wikimedia.org/wikipedia/en/thum...
# 96   https://upload.wikimedia.org/wikipedia/en/thum...
# 99   https://upload.wikimedia.org/wikipedia/en/thum...
# 100  https://upload.wikimedia.org/wikipedia/en/thum...
# 105  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values('title_x', ascending = False)
# Out:
#                   title_x    imdb_id  \
# 1623             Zubeidaa  tt0255713
# 1224         Zinda (film)  tt0488906
# 560       Zid (2014 film)  tt4228746
# 1312                Zeher  tt0451983
# 1035             Yuvvraaj  tt1105747
# ...                   ...        ...
# 886   Aakrosh (2010 film)  tt1708453
# 1055             68 Pages  tt1151299
# 1135        36 China Town  tt0477252
# 912              3 Idiots  tt1187043
# 1039     1971 (2007 film)  tt0983990
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1224  https://upload.wikimedia.org/wikipedia/en/thum...
# 560   https://upload.wikimedia.org/wikipedia/en/thum...
# 1312  https://upload.wikimedia.org/wikipedia/en/c/ce...
# 1035  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 886   https://upload.wikimedia.org/wikipedia/en/thum...
# 1055  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
stud = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)

# %%
stud
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
#Question is 2001 mai jo movies hai woh mai numbers wise sort karna chahati hu aur fir baaki movies ko mai 
#mai alphabetically sort karna chahati hu

# %%
movies.sort_values(["year_of_release","title_x"])
#toh ismai humne initially year of release se values sort ki hai aur second case mai title_x ke hisab se ascending way 
#se values arrange ki hai
# Out:
#                            title_x     imdb_id  \
# 1575                   Aalavandhan   tt0294264
# 1579           Ajnabee (2001 film)   tt0278291
# 1578               Aks (2001 film)   tt0289845
# 1581                  Aśoka (film)   tt0249371
# 1588                  Daman (film)   tt0273164
# ...                            ...         ...
# 96                Raid (2018 film)   tt7363076
# 116                          Sanju   tt6452574
# 123   Satyameva Jayate (2018 film)   tt8202612
# 37               Article 15 (film)  tt10324144
# 11                       Gully Boy   tt2395469
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# 1581  https://upload.wikimedia.org/wikipedia/en/thum...
# 1588  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(["year_of_release","title_x"], ascending=[True,False])
#ismai humne year of release ko in ascending order arrange kiya hai aur title ko descending order se release kiya hai
# Out:
#                       title_x     imdb_id  \
# 1623                 Zubeidaa   tt0255713
# 1573      Yaadein (2001 film)   tt0248617
# 1621                  Tum Bin   tt0290326
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1601         Maya (2001 film)   tt0299027
# ...                       ...         ...
# 112   Bhavesh Joshi Superhero   tt6129302
# 99                   Baaghi 2   tt6843812
# 87                    Aiyaary   tt6774212
# 11                  Gully Boy   tt2395469
# 37          Article 15 (film)  tt10324144
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1573  https://upload.wikimedia.org/wikipedia/en/thum...
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 1601  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 112   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# #### RANK: Rank is applicable only on Series DataFrame k upar kaam nahi karta

# %%
batsman = pd.read_csv("batsman_runs_ipl.csv")

# %%
batsman.sample(2)
# Out:
#          batter  batsman_run
# 397     PR Shah           92
# 498  SM Harwood            9

# %%
#let us find the rank of the batsman using rank function but humko rank descending format mai chahiye kyunki rank hum highest
# ko 1 denege matlab ulta hoga
batsman['batsman_rank'] = batsman["batsman_run"].rank(ascending=False)

# %%
batsman.sort_values('batsman_rank')
# Out:
#            batter  batsman_run  batsman_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 512   SS Cottrell            0         594.0
# 466     S Kaushik            0         594.0
# 203     IC Pandey            0         594.0
# 467       S Ladda            0         594.0
# 468  S Lamichhane            0         594.0
#
# [605 rows x 3 columns]

# %%
marks_data = {
    'history' : 45,
    'geography':34,
    'maths':80,
    'science':90
}

# %%
marks_data = pd.Series(marks_data)

# %%
marks_data
# Out:
# history      45
# geography    34
# maths        80
# science      90
# dtype: int64

# %%
marks_data.sort_index()
# Out:
# geography    34
# history      45
# maths        80
# science      90
# dtype: int64

# %%
movies.sort_index(ascending=False)
#ye index ko sort karta hai
# Out:
#                       title_x     imdb_id  \
# 1623                 Zubeidaa   tt0255713
# 1621                  Tum Bin   tt0290326
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1601         Maya (2001 film)   tt0299027
# 1600                   Kasoor   tt0272688
# ...                       ...         ...
# 96           Raid (2018 film)   tt7363076
# 87                    Aiyaary   tt6774212
# 37          Article 15 (film)  tt10324144
# 34              Yeh Hai India   tt5525846
# 11                  Gully Boy   tt2395469
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 1601  https://upload.wikimedia.org/wikipedia/en/thum...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#can set column name as the index because sometimes columna name also can be unique
batsman.set_index("batter", inplace= True)

# %%
batsman
# Out:
#                 batsman_run  batsman_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
#how to get old dataframe back
batsman.reset_index()
# Out:
#              batter  batsman_run  batsman_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
batsman.set_index("batsman_rank")
# Out:
#               batsman_run
# batsman_rank
# 166.5                 280
# 226.0                 161
# 535.0                   4
# 329.0                  53
# 402.5                  25
# ...                   ...
# 594.0                   0
# 343.0                  47
# 547.5                   3
# 27.0                 2754
# 256.0                 117
#
# [605 rows x 1 columns]

# %%
#jab hume koi aur column ko index set karna hai toh pehle hume reset index karna hoga aur fir uske baad firse index set karna hoga
batsman.reset_index().set_index("batsman_run")
# Out:
#                      batter  batsman_rank
# batsman_run
# 280          A Ashish Reddy         166.5
# 161                A Badoni         226.0
# 4                A Chandila         535.0
# 53                 A Chopra         329.0
# 25              A Choudhary         402.5
# ...                     ...           ...
# 0                Yash Dayal         594.0
# 47            Yashpal Singh         343.0
# 3               Younis Khan         547.5
# 2754           Yuvraj Singh          27.0
# 117                  Z Khan         256.0
#
# [605 rows x 2 columns]

# %%
#agar aap ek series ke upar reset index lagate ho toh kya hota hai.Toh woh dataframe ban jata hai.
marks_data.reset_index()
# Out:
#        index   0
# 0    history  45
# 1  geography  34
# 2      maths  80
# 3    science  90

# %%
type(marks_data.reset_index())
# Out:
# pandas.core.frame.DataFrame

# %%
#Using rename to rename column names
movies.rename(columns={'imdb_id':'imdb','poster_path':'link'},inplace = True)

# %%
#setting index on first column
movies.set_index('title_x')
# Out:
#                                imdb  \
# title_x
# Gully Boy                 tt2395469
# Yeh Hai India             tt5525846
# Article 15 (film)        tt10324144
# Aiyaary                   tt6774212
# Raid (2018 film)          tt7363076
# ...                             ...
# Kasoor                    tt0272688
# Maya (2001 film)          tt0299027
# Nayak (2001 Hindi film)   tt0291376
# Tum Bin                   tt0290326
# Zubeidaa                  tt0255713
#
#                                                                       link  \
# title_x
# Gully Boy                https://upload.wikimedia.org/wikipedia/en/thum...
# Yeh Hai India            https://upload.wikimedia.org/wikipedia/en/thum...
# Article 15 (film)        https://upload.wikimedia.org/wikipedia/en/thum...
# Aiyaary                  https://upload.wikimedia.org/wikipedia/en/thum...
# Raid (2018 film)         https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#how to rename index values of a dataframe
movies.rename(index = {'Tum Bin' : 'Tum'})
# Out:
#                       title_x        imdb  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                                    link  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#unique : only applicable to series and not to dataframe
temp = pd.Series([1,1,1,2,2,2,3,3,3, np.nan, np.nan])

# %%
temp.unique()
# Out:
# array([ 1.,  2.,  3., nan])

# %%
ipl['Season']
# Out:
# 0         2022
# 1         2022
# 2         2022
# 3         2022
# 4         2022
#         ...
# 945    2007/08
# 946    2007/08
# 947    2007/08
# 948    2007/08
# 949    2007/08
# Name: Season, Length: 950, dtype: object

# %%
#Find out all the unique seasons of IPL
ipl['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
# Find out the length of unqiue seasons of ipl
len(ipl['Season'].unique())
# Out:
# 15

# %%
#ye upar ke two setps hum single line mai bhi kar sakte hai by using nunique kyunki nunique apko directly length bata dega
#but ek cheez hai ki nunique nan ko count nahi karta
ipl['Season'].nunique()
# Out:
# 15

# %%
len(temp.unique())
# Out:
# 4

# %%
temp.nunique() #did not count nan values
# Out:
# 3

# %%
#isnull/null

# %%
stud
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
#isnull : applicable to both series and dataframe
stud.isnull() #ye check karega ki missing values hai ya nahi. Agar missing values hai toh True se replace kar dega agar 
#agar missing values nahi hai toh False se replace kar dega
# Out:
#     name  college  branch   cgpa  package
# 0  False    False   False  False    False
# 1  False    False   False  False    False
# 2  False    False   False  False    False
# 3   True     True    True   True     True
# 4  False     True   False  False    False
# 5   True    False   False  False    False
# 6  False    False   False  False    False
# 7   True     True   False  False    False
# 8  False     True   False  False     True
# 9   True    False    True   True     True

# %%
stud['name'][stud['name'].isnull()]
# Out:
# 3    NaN
# 5    NaN
# 7    NaN
# 9    NaN
# Name: name, dtype: object

# %%
stud['name'][stud['name'].notnull()] #isnull and notnull complimentary hai. notnull opposite deta hai
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 4    mrityunjay
# 6       rishabh
# 8        aditya
# Name: name, dtype: object

# %%
stud['name'].hasnans # sirf series pe kaam karta hai
# Out:
# True

# %%
stud.notnull()
# Out:
#     name  college  branch   cgpa  package
# 0   True     True    True   True     True
# 1   True     True    True   True     True
# 2   True     True    True   True     True
# 3  False    False   False  False    False
# 4   True    False    True   True     True
# 5  False     True    True   True     True
# 6   True     True    True   True     True
# 7  False    False    True   True     True
# 8   True    False    True   True    False
# 9  False     True   False  False    False

# %%
stud.dropna
# Out:
# <bound method DataFrame.dropna of          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN>

# %%
#dropna(series + dataframe) -> how parameter -> works like or
#kisi row mai agar ek bhi missing value hai toh pure ke pure row ko hi hata dena. ye hota hai default behavior of dropna
#ye default behavior aa raha hai how = any value se.
#agar hum change kare ki how = all karde toh bas wahi rows hatenge jaha sirf saare columns mai ek sath missing values hai
stud.dropna(how='all')
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
#hum aise bhi kar sakte hai ki wahi rows rakh sakte hai jaha name ka values missing hai
#jaha name ka value missing hai hum woh rows hata sakte hai
stud.dropna(subset=['name'])
# Out:
#          name college branch  cgpa  package
# 0      nitish     bit    eee  6.66      4.0
# 1       ankit     iit     it  8.25      5.0
# 2      rupesh     vit    cse  6.41      6.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 6     rishabh    ssit    civ  7.40      8.0
# 8      aditya     NaN    bio  7.40      NaN

# %%
#dropping na on basis of two columns
stud.dropna(subset=['name','college'])
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %%
#fillna (Series + dataframe)

# %%
stud['name'].fillna('unkown')
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3        unkown
# 4    mrityunjay
# 5        unkown
# 6       rishabh
# 7        unkown
# 8        aditya
# 9        unkown
# Name: name, dtype: object

# %%
stud['name'].fillna('unkown').hasnans
# Out:
# False

# %%
students.fillna(0) #but aise nahi karna chahiye kyunki ye logical nahi hai.kyunki person ka naam toh 0 nahi ho sakta na. 
#apko hamehsa alag alag columns ki values ko alag alag fill karna chahiye depending on its data type
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3           0       0      0   0.00      0.0
# 4  mrityunjay       0     me   5.60      6.0
# 5           0    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7           0       0    cse  10.00      9.0
# 8      aditya       0    bio   7.40      0.0
# 9           0     git      0   0.00      0.0

# %%
#lets fill package column with mean value of package
stud['package'].fillna(stud['package'].mean())
# Out:
# 0    4.000000
# 1    5.000000
# 2    6.000000
# 3    6.428571
# 4    6.000000
# 5    7.000000
# 6    8.000000
# 7    9.000000
# 8    6.428571
# 9    6.428571
# Name: package, dtype: float64

# %%
stud['name'].fillna(method = 'ffill') #forwardfill
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3        rupesh
# 4    mrityunjay
# 5    mrityunjay
# 6       rishabh
# 7       rishabh
# 8        aditya
# 9        aditya
# Name: name, dtype: object

# %%
stud['name'].fillna(method = 'bfill') #prefill
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3    mrityunjay
# 4    mrityunjay
# 5       rishabh
# 6       rishabh
# 7        aditya
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %%
student
# Out:
#    percent   iq   lpa country
# 0      120  130  3000   India
# 1       30   45  4500   India
# 2       45   34  7890   India
# 3      120  130  3000   India

# %%
#dropduplicates ( series + dataframe ) -> works like and -> duplicated()

# %%
student.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
student.duplicated().sum()
# Out:
# 1

# %%
temp
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     2.0
# 4     2.0
# 5     2.0
# 6     3.0
# 7     3.0
# 8     3.0
# 9     NaN
# 10    NaN
# dtype: float64

# %%
temp.drop_duplicates()
# Out:
# 0    1.0
# 3    2.0
# 6    3.0
# 9    NaN
# dtype: float64

# %%
student
# Out:
#    percent   iq   lpa country
# 0      120  130  3000   India
# 1       30   45  4500   India
# 2       45   34  7890   India
# 3      120  130  3000   India

# %%
#jab hum drop duplicates karte hai toh hum decide kar sakte hai ki hume 1st occurence of duplicate value rakhni hai ya second

# %%
student.drop_duplicates(keep = 'first')
# Out:
#    percent   iq   lpa country
# 0      120  130  3000   India
# 1       30   45  4500   India
# 2       45   34  7890   India

# %%
student.drop_duplicates(keep = 'last')
# Out:
#    percent   iq   lpa country
# 1       30   45  4500   India
# 2       45   34  7890   India
# 3      120  130  3000   India

# %%
#find the last match played by virat kolhi in delhi

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl["All Players"] = ipl["Team1Players"] + ipl["Team2Players"]
